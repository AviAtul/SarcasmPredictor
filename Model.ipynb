# %%
import json
import tensorflow as tf

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
vocab_size = 10000
embedding_dim = 16
max_length = 100
trunc_type='post'
padding_type='post'
oov_tok = "<OOV>"
training_size = 20000

# %%
with open("sarcasm.json", 'r') as f:
    datastore = json.load(f)

sentences = []
labels = []

for item in datastore:
    sentences.append(item['headline'])
    labels.append(item['is_sarcastic'])

# %%
training_sentences = sentences[0:training_size]
testing_sentences = sentences[training_size:]
training_labels = labels[0:training_size]
testing_labels = labels[training_size:]

# %%
tokenizer = Tokenizer(num_words=vocab_size, oov_token=oov_tok)
tokenizer.fit_on_texts(training_sentences)

word_index = tokenizer.word_index

# %%
training_sequences = tokenizer.texts_to_sequences(training_sentences)
training_padded = pad_sequences(training_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

testing_sequences = tokenizer.texts_to_sequences(testing_sentences)
testing_padded = pad_sequences(testing_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

# %%
import numpy as np
training_padded = np.array(training_padded)
training_labels = np.array(training_labels)
testing_padded = np.array(testing_padded)
testing_labels = np.array(testing_labels)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.GlobalAveragePooling1D(),
    tf.keras.layers.Dense(24, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 100, 16)           160000
#
#  global_average_pooling1d (G  (None, 16)               0
#  lobalAveragePooling1D)
#
#  dense (Dense)               (None, 24)                408
#
#  dense_1 (Dense)             (None, 1)                 25
#
# =================================================================
# Total params: 160,433
# Trainable params: 160,433
# Non-trainable params: 0
# _________________________________________________________________

# %%
num_epochs = 30
history = model.fit(training_padded, training_labels, epochs=num_epochs, 
                    validation_data=(testing_padded, testing_labels), verbose=2)
# Out:
# Epoch 1/30
# 625/625 - 7s - loss: 0.6652 - accuracy: 0.5878 - val_loss: 0.5673 - val_accuracy: 0.7863 - 7s/epoch - 11ms/step
# Epoch 2/30
# 625/625 - 4s - loss: 0.4177 - accuracy: 0.8359 - val_loss: 0.3831 - val_accuracy: 0.8365 - 4s/epoch - 7ms/step
# Epoch 3/30
# 625/625 - 4s - loss: 0.3064 - accuracy: 0.8777 - val_loss: 0.3630 - val_accuracy: 0.8368 - 4s/epoch - 7ms/step
# Epoch 4/30
# 625/625 - 5s - loss: 0.2560 - accuracy: 0.8996 - val_loss: 0.3461 - val_accuracy: 0.8521 - 5s/epoch - 7ms/step
# Epoch 5/30
# 625/625 - 4s - loss: 0.2206 - accuracy: 0.9134 - val_loss: 0.3436 - val_accuracy: 0.8566 - 4s/epoch - 7ms/step
# Epoch 6/30
# 625/625 - 4s - loss: 0.1946 - accuracy: 0.9263 - val_loss: 0.3579 - val_accuracy: 0.8541 - 4s/epoch - 7ms/step
# Epoch 7/30
# 625/625 - 4s - loss: 0.1727 - accuracy: 0.9334 - val_loss: 0.3646 - val_accuracy: 0.8533 - 4s/epoch - 6ms/step
# Epoch 8/30
# 625/625 - 4s - loss: 0.1542 - accuracy: 0.9431 - val_loss: 0.3817 - val_accuracy: 0.8498 - 4s/epoch - 6ms/step
# Epoch 9/30
# 625/625 - 4s - loss: 0.1393 - accuracy: 0.9505 - val_loss: 0.3975 - val_accuracy: 0.8533 - 4s/epoch - 6ms/step
# Epoch 10/30
# 625/625 - 4s - loss: 0.1248 - accuracy: 0.9567 - val_loss: 0.4184 - val_accuracy: 0.8504 - 4s/epoch - 7ms/step
# Epoch 11/30
# 625/625 - 4s - loss: 0.1149 - accuracy: 0.9590 - val_loss: 0.4580 - val_accuracy: 0.8377 - 4s/epoch - 7ms/step
# Epoch 12/30
# 625/625 - 4s - loss: 0.1038 - accuracy: 0.9649 - val_loss: 0.4755 - val_accuracy: 0.8420 - 4s/epoch - 7ms/step
# Epoch 13/30
# 625/625 - 4s - loss: 0.0954 - accuracy: 0.9673 - val_loss: 0.4896 - val_accuracy: 0.8432 - 4s/epoch - 7ms/step
# Epoch 14/30
# 625/625 - 4s - loss: 0.0863 - accuracy: 0.9708 - val_loss: 0.5213 - val_accuracy: 0.8417 - 4s/epoch - 7ms/step
# Epoch 15/30
# 625/625 - 4s - loss: 0.0787 - accuracy: 0.9747 - val_loss: 0.5505 - val_accuracy: 0.8378 - 4s/epoch - 7ms/step
# Epoch 16/30
# 625/625 - 4s - loss: 0.0729 - accuracy: 0.9766 - val_loss: 0.6046 - val_accuracy: 0.8310 - 4s/epoch - 6ms/step
# Epoch 17/30
# 625/625 - 4s - loss: 0.0661 - accuracy: 0.9788 - val_loss: 0.6171 - val_accuracy: 0.8338 - 4s/epoch - 7ms/step
# Epoch 18/30
# 625/625 - 4s - loss: 0.0607 - accuracy: 0.9812 - val_loss: 0.6435 - val_accuracy: 0.8305 - 4s/epoch - 7ms/step
# Epoch 19/30
# 625/625 - 4s - loss: 0.0556 - accuracy: 0.9825 - val_loss: 0.6986 - val_accuracy: 0.8287 - 4s/epoch - 7ms/step
# Epoch 20/30
# 625/625 - 4s - loss: 0.0506 - accuracy: 0.9845 - val_loss: 0.7221 - val_accuracy: 0.8265 - 4s/epoch - 6ms/step
# Epoch 21/30
# 625/625 - 4s - loss: 0.0453 - accuracy: 0.9862 - val_loss: 0.7752 - val_accuracy: 0.8222 - 4s/epoch - 7ms/step
# Epoch 22/30
# 625/625 - 4s - loss: 0.0433 - accuracy: 0.9869 - val_loss: 0.7976 - val_accuracy: 0.8222 - 4s/epoch - 7ms/step
# Epoch 23/30
# 625/625 - 4s - loss: 0.0399 - accuracy: 0.9880 - val_loss: 0.8213 - val_accuracy: 0.8225 - 4s/epoch - 7ms/step
# Epoch 24/30
# 625/625 - 4s - loss: 0.0365 - accuracy: 0.9887 - val_loss: 0.8601 - val_accuracy: 0.8180 - 4s/epoch - 7ms/step
# Epoch 25/30
# 625/625 - 4s - loss: 0.0359 - accuracy: 0.9898 - val_loss: 0.8918 - val_accuracy: 0.8201 - 4s/epoch - 7ms/step
# Epoch 26/30
# 625/625 - 4s - loss: 0.0308 - accuracy: 0.9910 - val_loss: 0.9287 - val_accuracy: 0.8176 - 4s/epoch - 7ms/step
# Epoch 27/30
# 625/625 - 4s - loss: 0.0294 - accuracy: 0.9918 - val_loss: 0.9685 - val_accuracy: 0.8173 - 4s/epoch - 7ms/step
# Epoch 28/30
# 625/625 - 4s - loss: 0.0257 - accuracy: 0.9927 - val_loss: 1.0073 - val_accuracy: 0.8153 - 4s/epoch - 7ms/step
# Epoch 29/30
# 625/625 - 4s - loss: 0.0241 - accuracy: 0.9938 - val_loss: 1.0427 - val_accuracy: 0.8147 - 4s/epoch - 7ms/step
# Epoch 30/30
# 625/625 - 4s - loss: 0.0239 - accuracy: 0.9932 - val_loss: 1.0872 - val_accuracy: 0.8103 - 4s/epoch - 7ms/step

# %%
import matplotlib.pyplot as plt


def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()
  
plot_graphs(history, "accuracy")
plot_graphs(history, "loss")
